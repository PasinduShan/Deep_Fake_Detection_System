# %%
# !pip install numpy -q
# !pip install pandas -q
# !pip install matplotlib -q
# !pip install tensorflow -q
# !pip install opencv-python -q
# Out:
# [notice] A new release of pip available: 22.3 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.3 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.3 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.3 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.3 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import time
import cv2

BATCH_SIZE = 32
IMAGE_SIZE = (128, 128)
DATASET_PATH = 'D:/Projects/FYP-DeepFakeDetection/Dataset'

# Load dataset
train_data = tf.keras.preprocessing.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE
)

validation_data = tf.keras.preprocessing.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE
)

test_data = tf.keras.preprocessing.image_dataset_from_directory(
    DATASET_PATH,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

class_names = train_data.class_names

# Plot data sample
plt.figure(figsize=(10, 4))
for image, label in train_data.take(1):
    for i in range(10):
        ax = plt.subplot(2, 5, i + 1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(class_names[label[i]])
        plt.axis('off')

# Normalize dataset
train_data = train_data.map(lambda x, y: (x / 255, y))
validation_data = validation_data.map(lambda x, y: (x / 255, y))
test_data = test_data.map(lambda x, y: (x / 255, y))

# Data augmentation
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal", input_shape=(128, 128, 3)),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2),
])

# Model building
model = tf.keras.models.Sequential([
    data_augmentation,
    tf.keras.layers.Conv2D(32, kernel_size=3, activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(64, kernel_size=3, activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(128, kernel_size=3, activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile model
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy'])

# Model training
start_time = time.time()
history = model.fit(train_data, epochs=20, validation_data=validation_data)
end_time = time.time()

print(f'Total time for training {(end_time - start_time):.3f} seconds')

# Plotting the loss and accuracy
fig = plt.figure()
plt.plot(history.history['loss'], color='teal', label='loss')
plt.plot(history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend()
plt.show()

fig = plt.figure()
plt.plot(history.history['accuracy'], color='teal', label='accuracy')
plt.plot(history.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend()
plt.show()

# Evaluate precision, recall, and accuracy
precision = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()
accuracy = tf.keras.metrics.BinaryAccuracy()

for batch in test_data.as_numpy_iterator():
    X, y = batch
    yhat = model.predict(X)
    precision.update_state(y, yhat)
    recall.update_state(y, yhat)
    accuracy.update_state(y, yhat)

print(f'Precision: {precision.result().numpy()}')
print(f'Recall: {recall.result().numpy()}')
print(f'Accuracy: {accuracy.result().numpy()}')

# Load and predict on a single image
img = cv2.imread('D:/Projects/FYP-DeepFakeDetection/Sample/fake.jpg')
resized_image = tf.image.resize(img, IMAGE_SIZE)
scaled_image = resized_image / 255.0

# Expand dimensions to match the input shape expected by the model
yhat = model.predict(np.expand_dims(scaled_image, 0))

if yhat > 0.5:
    print(f'{class_names[1]}')
else:
    print(f'{class_names[0]}')
# Out:
# Found 1838 files belonging to 2 classes.
# Using 1471 files for training.
# Found 1838 files belonging to 2 classes.
# Using 367 files for validation.
# Found 1838 files belonging to 2 classes.
# Epoch 1/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 18s 325ms/step - accuracy: 0.5257 - loss: 0.7543 - val_accuracy: 0.5695 - val_loss: 0.6880
# Epoch 2/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 315ms/step - accuracy: 0.5636 - loss: 0.6803 - val_accuracy: 0.5695 - val_loss: 0.6828
# Epoch 3/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 312ms/step - accuracy: 0.5968 - loss: 0.6721 - val_accuracy: 0.5722 - val_loss: 0.6852
# Epoch 4/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 313ms/step - accuracy: 0.5832 - loss: 0.6757 - val_accuracy: 0.5559 - val_loss: 0.6808
# Epoch 5/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 307ms/step - accuracy: 0.5731 - loss: 0.6722 - val_accuracy: 0.5504 - val_loss: 0.6885
# Epoch 6/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 309ms/step - accuracy: 0.5920 - loss: 0.6729 - val_accuracy: 0.5695 - val_loss: 0.6797
# Epoch 7/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 313ms/step - accuracy: 0.5557 - loss: 0.7013 - val_accuracy: 0.5749 - val_loss: 0.6784
# Epoch 8/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 312ms/step - accuracy: 0.6002 - loss: 0.6740 - val_accuracy: 0.5695 - val_loss: 0.6826
# Epoch 9/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 312ms/step - accuracy: 0.5988 - loss: 0.6641 - val_accuracy: 0.5722 - val_loss: 0.6782
# Epoch 10/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 311ms/step - accuracy: 0.5848 - loss: 0.6776 - val_accuracy: 0.5695 - val_loss: 0.7049
# Epoch 11/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 313ms/step - accuracy: 0.5909 - loss: 0.6727 - val_accuracy: 0.5695 - val_loss: 0.7424
# Epoch 12/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 312ms/step - accuracy: 0.6017 - loss: 0.6761 - val_accuracy: 0.5722 - val_loss: 0.7098
# Epoch 13/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 310ms/step - accuracy: 0.5926 - loss: 0.6722 - val_accuracy: 0.4632 - val_loss: 0.7581
# Epoch 14/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 310ms/step - accuracy: 0.6004 - loss: 0.6603 - val_accuracy: 0.5640 - val_loss: 0.6776
# Epoch 15/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 314ms/step - accuracy: 0.5829 - loss: 0.6767 - val_accuracy: 0.5777 - val_loss: 0.6722
# Epoch 16/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 313ms/step - accuracy: 0.6002 - loss: 0.6603 - val_accuracy: 0.5940 - val_loss: 0.6687
# Epoch 17/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 311ms/step - accuracy: 0.5901 - loss: 0.6636 - val_accuracy: 0.5749 - val_loss: 0.7639
# Epoch 18/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 316ms/step - accuracy: 0.5882 - loss: 0.6722 - val_accuracy: 0.5477 - val_loss: 0.6969
# Epoch 19/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 313ms/step - accuracy: 0.5816 - loss: 0.6702 - val_accuracy: 0.5858 - val_loss: 0.7593
# Epoch 20/20
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 316ms/step - accuracy: 0.6115 - loss: 0.6570 - val_accuracy: 0.6076 - val_loss: 0.6788
# Total time for training 294.130 seconds
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Precision: 0.6102313995361328
# Recall: 0.9277777671813965
# Accuracy: 0.609358012676239
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# real

# %%
# Load and predict on a single image
img = cv2.imread('D:/Projects/FYP-DeepFakeDetection/Sample/real.jpg')
resized_image = tf.image.resize(img, IMAGE_SIZE)
scaled_image = resized_image / 255.0

# Expand dimensions to match the input shape expected by the model
yhat = model.predict(np.expand_dims(scaled_image, 0))

if yhat > 0.5:
    print(f'{class_names[1]}')
else:
    print(f'{class_names[0]}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# real
